# %%
# Самое крупное ревью по теме: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5233461/

# %%
import numpy as np
import matplotlib.pylab as plt
from skimage.feature import peak_local_max

# %%
# !ls cytology_dataset/dataset/frame000_stack/
# Out:
# fov000.png  fov004.png	fov008.png  fov012.png	fov016.png
# fov001.png  fov005.png	fov009.png  fov013.png	fov017.png
# fov002.png  fov006.png	fov010.png  fov014.png	fov018.png
# fov003.png  fov007.png	fov011.png  fov015.png	fov019.png

# %%
data = plt.imread('./cytology_dataset/dataset/frame010_stack/fov001.png')

# %%
plt.imshow(data)
plt.colorbar()
plt.show()
locations = peak_local_max(-data, min_distance=30, threshold_abs=-0.4)
plt.imshow(data)
plt.colorbar()
plt.scatter(locations[:,1], locations[:,0], color='red')

# %%
peak_local_max?
